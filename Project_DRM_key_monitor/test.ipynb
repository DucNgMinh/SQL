# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv('output.csv')
df.columns = ['Date', 'Number_of_customers']
df
# Out:
#            Date  Number_of_customers
# 0    2019-05-01                 9367
# 1    2019-05-02                 7236
# 2    2019-05-03                 7697
# 3    2019-05-04                 8540
# 4    2019-05-05                 8868
# ..          ...                  ...
# 393  2020-05-28                10022
# 394  2020-05-29                10033
# 395  2020-05-30                12400
# 396  2020-05-31                12019
# 397  2020-06-01                 9142
#
# [398 rows x 2 columns]

# %%
ax, fig = plt.subplots(1,1,figsize= (15,6))
plt.plot(df['Date'],df['Number_of_customers'])
